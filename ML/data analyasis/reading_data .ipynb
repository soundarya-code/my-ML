# %% [markdown]
# # reading csv and txt file

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('btc-market-price.csv')

# %% [markdown]
# #### Reading with python

# %%
filepath='btc-market-price.csv'
with open(filepath,'r') as reader:
    print(reader)
# Out:
# <_io.TextIOWrapper name='btc-market-price.csv' mode='r' encoding='cp1252'>

# %%
filepath='btc-market-price.csv'
with open(filepath,'r') as reader:
    for index,line in enumerate(reader.readlines()):
        print(index,line)
#         if(index<10):
# Out:
# 0 2017-04-02 00:00:00,1099.169125
#
# 1 2017-04-03 00:00:00,1141.813
#
# 2 2017-04-04 00:00:00,1141.6003625
#
# 3 2017-04-05 00:00:00,1133.0793142857142
#
# 4 2017-04-06 00:00:00,1196.3079375
#
# 5 2017-04-07 00:00:00,1190.45425
#
# 6 2017-04-08 00:00:00,1181.1498375
#
# 7 2017-04-09 00:00:00,1208.8005
#
# 8 2017-04-10 00:00:00,1207.744875
#
# 9 2017-04-11 00:00:00,1226.6170375
#
# 10 2017-04-12 00:00:00,1218.92205
#
# 11 2017-04-13 00:00:00,1180.0237125
#
# 12 2017-04-14 00:00:00,1185.2600571428572
#
# 13 2017-04-15 00:00:00,1184.8806714285713
#
# 14 2017-04-16 00:00:00,1186.9274125
#
# 15 2017-04-17 00:00:00,1205.634875
#
# 16 2017-04-18 00:00:00,1216.1867428571427
#
# 17 2017-04-19 00:00:00,1217.9300875
#
# 18 2017-04-20 00:00:00,1241.6863250000001
#
# 19 2017-04-21 00:00:00,1258.3614125
#
# 20 2017-04-22 00:00:00,1261.311225
#
# 21 2017-04-23 00:00:00,1257.9881125
#
# 22 2017-04-24 00:00:00,1262.902775
#
# 23 2017-04-25 00:00:00,1279.4146875000001
#
# ...

# %% [markdown]
# # Reading  our first  CSV File

# %%
filepath="https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"
df=pd.read_csv(filepath,header=None,na_values=['','?','-']).head()

# %%
df.head()
# Out:
#               0             1     2                 3
# 0  Country Name  Country Code  Year             Value
# 1    Arab World           ARB  1968  25760683041.0857
# 2    Arab World           ARB  1969  28434203615.4829
# 3    Arab World           ARB  1970  31385499664.0672
# 4    Arab World           ARB  1971  36426909888.3928

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},parse_dates=[0])

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2017-04-02
# 1   2017-04-03
# 2   2017-04-04
# 3   2017-04-05
# 4   2017-04-06
# Name: Timestamp, dtype: datetime64[ns]

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-04-02  1099.169125
# 1 2017-04-03  1141.813000
# 2 2017-04-04  1141.600363
# 3 2017-04-05  1133.079314
# 4 2017-04-06  1196.307937

# %%
df4= pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0],
                 index_col=[0])

# %% [markdown]
# # A more changes

# %%
exam_df=pd.read_csv('exam_review.csv',sep='>')

# %%
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
exam_df=pd.read_csv('exam_review.csv',sep='>',decimal=',')

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_df=pd.read_csv('exam_review.csv',sep='>',thousands=',')

# %% [markdown]
# # excluding specific row

# %%
exam_df=pd.read_csv('exam_review.csv',sep='>',skiprows=2)

# %%
exam_df
# Out:
#    Melvin   Scott  24      77  83
# 0  Amirah   Haley  22      92  67
# 1  Gerard   Mills  19  78,000  72
# 2     Amy  Grimes  23      91  81

# %% [markdown]
# As the header is considered as the first row, to skip reading data rows 1 and 3, we can use skiprows=[1,3]:

# %%
exam_df=pd.read_csv('exam_review.csv',sep='>',skiprows=[1,3])

# %%
exam_df
# Out:
#   first_name last_name  age math_score  french_score
# 0     Melvin     Scott   24         77            83
# 1     Gerard     Mills   19     78,000            72
# 2        Amy    Grimes   23         91            81

# %%
pd.read_csv('exam_review.csv',sep='>',skip_blank_lines=False)
# Out:
#   first_name last_name   age math_score french_score
# 0        Ray    Morley  18.0     68,000       75,000
# 1     Melvin     Scott  24.0         77           83
# 2     Amirah     Haley  22.0         92           67
# 3        NaN       NaN   NaN        NaN          NaN
# 4     Gerard     Mills  19.0     78,000           72
# 5        Amy    Grimes  23.0         91           81

# %%
pd.read_csv('exam_review.csv',sep='>',skip_blank_lines=True)
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
pd.read_csv('exam_review.csv',sep='>',usecols=['first_name','last_name','age'])
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %%
pd.read_csv('exam_review.csv',sep='>',usecols=[1,0,3])
# Out:
#   first_name last_name math_score
# 0        Ray    Morley     68,000
# 1     Melvin     Scott         77
# 2     Amirah     Haley         92
# 3     Gerard     Mills     78,000
# 4        Amy    Grimes         91

# %% [markdown]
# # Using Series instead of dataframe

# %%
e=pd.read_csv('exam_review.csv',sep='>',usecols=[1])

# %%
type(e)
# Out:
# pandas.core.frame.DataFrame

# %%
e=pd.read_csv('exam_review.csv',sep='>',usecols=[1],squeeze=True)

# %%
e
# Out:
# 0    Morley
# 1     Scott
# 2     Haley
# 3     Mills
# 4    Grimes
# Name: last_name, dtype: object

# %%
type(e)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Save  to CSV file

# %%
exam_df
# Out:
#   first_name last_name  age math_score  french_score
# 0     Melvin     Scott   24         77            83
# 1     Gerard     Mills   19     78,000            72
# 2        Amy    Grimes   23         91            81

# %%
exam_df.to_csv('out.csv')

# %% [markdown]
# # Reading json files

# %%
import numpy as np
import pandas as pd

# %%
import json

# %%
from pandas.io.json import json_normalize

# %%
with open('artists.json')as file:
    json_dict=json.load(file)
artists=json_normalize(json_dict)
# Out:
# C:\Users\SOMASH~1\AppData\Local\Temp/ipykernel_812/1137661126.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   artists=json_normalize(json_dict)

# %%
biography=json_normalize(json_dict,record_path='bio',meta=['name'])
# Out:
# C:\Users\SOMASH~1\AppData\Local\Temp/ipykernel_812/1825729634.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   biography=json_normalize(json_dict,record_path='bio',meta=['name'])

# %%
artists.head()
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
artists.isnull().sum()
# Out:
# name           0
# years          0
# genre          0
# nationality    0
# bio            0
# dtype: int64

# %%
artists.shape
# Out:
# (5, 5)
