# %%
# !pip install sqlalchemy

# %%
import pandas as pd

# %% [markdown]
# #### Reading data from sql database

# %%
import sqlite3

# %%
conn=sqlite3.connect('chinook.db')

# %%
cur=conn.cursor()

# %%
cur.execute('select * from employees LIMIT 5;')

# %%
results=cur.fetchall()

# %%
results
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
# ...

# %%
df=pd.DataFrame(results)

# %%
df.head(5)
# Out:
#    0        1         2                    3    4                    5   \
# 0   1    Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2  Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3  Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4     Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5  Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
#
#                     6                    7         8   9       10       11  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton  AB  Canada  T5K 2N1
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary  AB  Canada  T2P 2T3
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary  AB  Canada  T2P 5M5
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary  AB  Canada  T2P 5G3
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary  AB  Canada  T3B 1Y7
#
#                   12                 13                        14
# ...

# %%
cur.close()

# %%
conn.close()

# %% [markdown]
# # Pandas read_sql method

# %%
conn=sqlite3.connect('chinook.db')

# %%
df=pd.read_sql('select * from employees',conn,index_col=['EmployeeId'],parse_dates=['BirthDate','HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
# ...

# %%
df.isna().sum()
# Out:
# LastName      0
# FirstName     0
# Title         0
# ReportsTo     1
# BirthDate     0
# HireDate      0
# Address       0
# City          0
# State         0
# Country       0
# PostalCode    0
# Phone         0
# Fax           0
# Email         0
# dtype: int64

# %% [markdown]
# # using of read_sql_query

# %%
conn=sqlite3.connect('chinook.db')

# %%
df=pd.read_sql_query('select * from employees',conn)

# %%
df=pd.read_sql_query('select * from employees',conn,parse_dates=['BirthDate ','HireDate'],index_col='EmployeeId')

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN
# 2           Edwards     Nancy        Sales Manager        1.0
# 3           Peacock      Jane  Sales Support Agent        2.0
# 4              Park  Margaret  Sales Support Agent        2.0
# 5           Johnson     Steve  Sales Support Agent        2.0
#
#                       BirthDate   HireDate              Address      City  \
# EmployeeId
# 1           1962-02-18 00:00:00 2002-08-14  11120 Jasper Ave NW  Edmonton
# 2           1958-12-08 00:00:00 2002-05-01         825 8 Ave SW   Calgary
# 3           1973-08-29 00:00:00 2002-04-01        1111 6 Ave SW   Calgary
# 4           1947-09-19 00:00:00 2003-05-03     683 10 Street SW   Calgary
# 5           1965-03-03 00:00:00 2003-10-17         7727B 41 Ave   Calgary
#
#            State Country PostalCode              Phone                Fax  \
# EmployeeId
# ...

# %% [markdown]
# # Read_sql_table

# %% [markdown]
# read_sql_table is a useful function, but it works only with SQLAlchemy, a Python SQL Toolkit and Object Relational Mapper.
#
# This is just a demonstration of its usage where we read the whole employees table.

# %% [markdown]
# # Creating tables from dataframe objects

# %% [markdown]
# Finally we can persist DataFrame objects we've working on in a database using the pandas to_sql method.
#
# Although it is easy to implement, it could be a very slow process.

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN
# 2           Edwards     Nancy        Sales Manager        1.0
# 3           Peacock      Jane  Sales Support Agent        2.0
# 4              Park  Margaret  Sales Support Agent        2.0
# 5           Johnson     Steve  Sales Support Agent        2.0
#
#                       BirthDate   HireDate              Address      City  \
# EmployeeId
# 1           1962-02-18 00:00:00 2002-08-14  11120 Jasper Ave NW  Edmonton
# 2           1958-12-08 00:00:00 2002-05-01         825 8 Ave SW   Calgary
# 3           1973-08-29 00:00:00 2002-04-01        1111 6 Ave SW   Calgary
# 4           1947-09-19 00:00:00 2003-05-03     683 10 Street SW   Calgary
# 5           1965-03-03 00:00:00 2003-10-17         7727B 41 Ave   Calgary
#
#            State Country PostalCode              Phone                Fax  \
# EmployeeId
# ...

# %%
df.to_sql('employees3',conn)

# %%
pd.read_sql_query('select * from employees3',conn,index_col='EmployeeId')
# Out:
#             LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1              Adams    Andrew      General Manager        NaN
# 2            Edwards     Nancy        Sales Manager        1.0
# 3            Peacock      Jane  Sales Support Agent        2.0
# 4               Park  Margaret  Sales Support Agent        2.0
# 5            Johnson     Steve  Sales Support Agent        2.0
# 6           Mitchell   Michael           IT Manager        1.0
# 7               King    Robert             IT Staff        6.0
# 8           Callahan     Laura             IT Staff        6.0
#
#                       BirthDate             HireDate  \
# EmployeeId
# 1           1962-02-18 00:00:00  2002-08-14 00:00:00
# 2           1958-12-08 00:00:00  2002-05-01 00:00:00
# 3           1973-08-29 00:00:00  2002-04-01 00:00:00
# 4           1947-09-19 00:00:00  2003-05-03 00:00:00
# 5           1965-03-03 00:00:00  2003-10-17 00:00:00
# ...

# %% [markdown]
# # Custom behaviour

# %% [markdown]
# The if_exists parameter define how to behave if the table already exists and adds a ton of flexibility, letting you decide wheather to replace current database data, append new data at the end, or simply fail if database already exists.

# %%
pd.DataFrame().to_sql('employees2',
                      conn,
                      if_exists='replace')

# %%
pd.read_sql_query('Select * from employees2',conn).head()
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
df.to_sql('employees2',conn,if_exists='replace')

# %%
df.read_sql_query('select * from  employees2',conn).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SOMASH~1\AppData\Local\Temp/ipykernel_8920/3976860669.py in <module>
# ----> 1 df.read_sql_query('select * from  employees2',conn).head()
#
# c:\python3.9\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'read_sql_query'
